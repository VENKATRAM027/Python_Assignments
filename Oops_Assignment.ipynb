# %%
#  Classes & Objects (Basics)

# %%
# Create a Student class with attributes name, age, and grade. Instantiate 3 objects and 
# print their details. 

class student:
    def __init__(self,name,age,grade):
        self.name = name
        self.age = age
        self.grade = grade

    def __str__(self):
        return f"Name : {self.name} , Age : {self.age} , Grade : {self.grade}"
    

student1 = student('Alice',26,'A')
student2 = student('sundar',46,'C')
student3 = student('Sam',29,'B')

print(student1)
print(student2)
print(student3)
# Out:
# Name : Alice , Age : 26 , Grade : A
# Name : sundar , Age : 46 , Grade : C
# Name : Sam , Age : 29 , Grade : B

# %%
# Build a BankAccount class with deposit and withdraw methods. 

class BankAccount:
    def __init__(self, account_holder,initial_balance = 0):
        self.account_holder = account_holder
        self.balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            return f"Deposited: Rs.{amount:.2f}. New Balance: Rs.{self.balance:.2f}"
        else:
            return "Deposit amount must be positive"

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.balance:
                self.balance -= amount
                return f"Withdrawn: Rs.{amount:.2f}. New Balance:{self.balance:.2f}"
            else:
                return "Insufficient Funds"
        else:
            return "Withdraw amount must be positive"

    def get_balance(self):
        return self.balance


account = BankAccount("venkat ram" , 45000)     
account.deposit(4500)   
account.withdraw(30000)  
account.withdraw(20000)     
print(f"Final balance for {account.account_holder}: Rs.{account.get_balance():.2f}")
# Out:
# Final balance for venkat ram: Rs.19500.00

# %%
# Create a class Rectangle and calculate its area and perimeter using methods.

class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height) 


rectangle1 = Rectangle(5,10)

print(f"Rectangle width: {rectangle1.width} , Height : {rectangle1.height}")
print(f"Area : {rectangle1.area()}")
print(f"Perimeter : {rectangle1.perimeter()}")
# Out:
# Rectangle width: 5 , Height : 10
# Area : 50
# Perimeter : 30

# %%
# Write a Book class with a method to display book info. 

class Book:
    def __init__(self, title, author, publication_year):
        self.title = title
        self.author = author
        self.publication_year = publication_year

    def display_info(self):
        info = (
            f"Title : {self.title}\n"
            f"Author : {self.author}\n"
            f"publication_year : {self.publication_year}"
        )
        return info

book1 = Book('Atomic habits','sam gill', 2012)
book1.display_info()
# Out:
# 'Title : Atomic habits\nAuthor : sam gill\npublication_year : 2012'
